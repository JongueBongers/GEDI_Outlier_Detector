# %% [markdown]
# # Outlier Detector Version Two
#
# - Features to add: Time of day, laser strength, long, lat, solar elev., azimuth ...
# - Assemble a massive file with all the data; each row is a shot
# - Use more files from GDrive, get 1000 files
# - Do a PCA on the massive file (exploratory data analysis)
# - Probably 1 or 2 RH metrics are enough for RH
# - Instrumentation data may work too
# - For clustering to work, we need to know where each cluster is -- we're really modeling the covariance matrices
# - "Given this set of data, can this point be drawn from this cov matrix?"
# - Look at cov within consecutive shots
# - Learn from different passes at different times (how?)
# - Idea: being aware of context
#
# ## Questions for Jim:
# - What does a good waveform need to satisfy?
# - Does it make sense?

# %%
import os
import random

import h5py
import numpy as np
import pandas as pd
import geopandas as gp
import geoviews as gv
from geoviews import opts, tile_sources as gvts
import holoviews as hv
gv.extension('bokeh', 'matplotlib')
from shapely.geometry import Point
import warnings
from shapely.errors import ShapelyDeprecationWarning
warnings.filterwarnings("ignore", category=ShapelyDeprecationWarning) 

import matplotlib
import matplotlib.pyplot as plt
import PyQt6
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1011'>
#   <div id="ee07bbb2-744e-4f8b-9557-2ebbe5c69335" data-root-id="p1011" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"098522cd-77ea-41c9-b97d-53764548a64b":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1011"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1012","attributes":{"plot_id":"p1011","comm_id":"cb7a0dc2d67b46d48fff53d4ce2364e1","client_comm_id":"c0711c0c9b514dd697ca66ba81011691"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"098522cd-77ea-41c9-b97d-53764548a64b","roots":{"p1011":"ee07bbb2-744e-4f8b-9557-2ebbe5c69335"},"root_ids":["p1011"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
inDir = os.getcwd() + "\\GEDI_sample_files"
print(inDir)
# input_file_names = [g for g in os.listdir(inDir) if g.startswith('GEDI02_A') and g.endswith('.h5')]  # List all GEDI level 2 files in inDir
input_file_names = ['GEDI02_A_2021086153349_O12964_03_T08275_02_003_02_V002.h5']
input_file_names
# Out:
# C:\Users\jingb\OneDrive\Documents\GEDI Outlier Detection\GEDI_sample_files
# ['GEDI02_A_2021086153349_O12964_03_T08275_02_003_02_V002.h5']

# %% [markdown]
# ### Loading files with RH information into a huge Pandas dataframe

# %%
input_files = []
files_to_beams = dict()
for n in input_file_names:
    file_path = os.path.join(inDir, n)  # Select an example file
    file = h5py.File(file_path, 'r')
    input_files.append(file)
    
    print('Loading file: ' + n)
    print('The file contains the following groups: ' + str(list(file.keys())))
    
    print("The file's metadata contains the following attributes: ")
    for g in file['METADATA']['DatasetIdentification'].attrs: print(g)
    
    beamNames = [g for g in file.keys() if g.startswith('BEAM')]
    files_to_beams[file] = beamNames
    
    print("The file contains the following beams: ")
    for b in beamNames: 
        print(f"{b} is a {file[b].attrs['description']}")
# Out:
# Loading file: GEDI02_A_2021086153349_O12964_03_T08275_02_003_02_V002.h5
# The file contains the following groups: ['BEAM0000', 'BEAM0001', 'BEAM0010', 'BEAM0011', 'BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011', 'METADATA']
# The file's metadata contains the following attributes:
# PGEVersion
# VersionID
# abstract
# characterSet
# creationDate
# credit
# fileName
# language
# originatorOrganizationName
# purpose
# shortName
# spatialRepresentationType
# status
# topicCategory
# uuid
# The file contains the following beams:
# BEAM0000 is a Coverage beam
# BEAM0001 is a Coverage beam
# BEAM0010 is a Coverage beam
# BEAM0011 is a Coverage beam
# BEAM0101 is a Full power beam
# BEAM0110 is a Full power beam
# BEAM1000 is a Full power beam
# BEAM1011 is a Full power beam

# %%
all_objs = []
all_datasets = []
file_to_rh = dict()
file_to_quality = dict()

for f in input_files:
    f.visit(all_objs.append) # Retrieve list of datasets
    local_datasets = [o for o in all_objs if isinstance(f[o], h5py.Dataset)]
    local_rh_datasets = [d for d in local_datasets if d.endswith('/rh')]
    
    local_quality_ds = [q for q in local_datasets if q.endswith('/quality_flag') and "rx" not in q]
    print(f'All quality_flag datasets: {local_quality_ds}')
    
    print(f'All RH datasets in file {f}: ' + str(local_rh_datasets))
    all_datasets.extend(local_datasets)  # Search for relevant SDS inside data file
    
    file_to_rh[f] = local_rh_datasets
    file_to_quality[f] = local_quality_ds

print('10 randomly selected objects: ' + str(random.sample(all_objs, 10)))
print('10 randomly selected datasets: ' + str(random.sample(all_datasets, 10)))
# Out:
# All quality_flag datasets: ['BEAM0000/quality_flag', 'BEAM0001/quality_flag', 'BEAM0010/quality_flag', 'BEAM0011/quality_flag', 'BEAM0101/quality_flag', 'BEAM0110/quality_flag', 'BEAM1000/quality_flag', 'BEAM1011/quality_flag']
# All RH datasets in file <HDF5 file "GEDI02_A_2021086153349_O12964_03_T08275_02_003_02_V002.h5" (mode r)>: ['BEAM0000/rh', 'BEAM0001/rh', 'BEAM0010/rh', 'BEAM0011/rh', 'BEAM0101/rh', 'BEAM0110/rh', 'BEAM1000/rh', 'BEAM1011/rh']
# 10 randomly selected objects: ['BEAM0001/rx_processing_a3/ancillary/rx_front_threshold', 'BEAM0010/rx_assess/ancillary', 'BEAM0101/rx_processing_a4/rx_modelocalenergy', 'BEAM0101/rx_processing_a1/min_detection_energy', 'BEAM1000/geolocation/lon_highestreturn_a5', 'BEAM0001/rx_processing_a4/rx_modeenergytobotloc', 'BEAM0000/rx_processing_a5/rx_iwaveamps', 'BEAM0101/beam', 'BEAM0011/rx_processing_a5/rx_modelocalslope', 'BEAM1000/degrade_flag']
# 10 randomly selected datasets: ['BEAM0000/rx_processing_a2/ancillary/ampval_limit3', 'BEAM1011/rx_processing_a4/ancillary/botlocdist_limit1', 'BEAM0110/geolocation/lon_highestreturn_a4', 'BEAM0110/rx_processing_a6/min_detection_threshold', 'BEAM0000/rx_processing_a6/selected_mode_flag', 'BEAM0101/rx_processing_a2/ancillary/rx_front_threshold', 'BEAM1011/rx_processing_a1/rx_algrunflag', 'BEAM1000/rx_processing_a6/ancillary/rx_front_threshold', 'BEAM1011/rx_processing_a2/rx_modelocalslope', 'BEAM0000/geolocation/lon_lowestmode_a4']

# %%
for f in input_files:
    print(f"File: {f.filename}")
    for b in files_to_beams[f]:
        print(f"Beam: {b}")
        print([ds for ds in all_datasets if b in ds][:])
# Out:
# File: C:\Users\jingb\OneDrive\Documents\GEDI Outlier Detection\GEDI_sample_files\GEDI02_A_2021086153349_O12964_03_T08275_02_003_02_V002.h5
# Beam: BEAM0000
# ['BEAM0000/ancillary/l2a_alg_count', 'BEAM0000/beam', 'BEAM0000/channel', 'BEAM0000/degrade_flag', 'BEAM0000/delta_time', 'BEAM0000/digital_elevation_model', 'BEAM0000/digital_elevation_model_srtm', 'BEAM0000/elev_highestreturn', 'BEAM0000/elev_lowestmode', 'BEAM0000/elevation_bias_flag', 'BEAM0000/elevation_bin0_error', 'BEAM0000/energy_total', 'BEAM0000/geolocation/elev_highestreturn_a1', 'BEAM0000/geolocation/elev_highestreturn_a2', 'BEAM0000/geolocation/elev_highestreturn_a3', 'BEAM0000/geolocation/elev_highestreturn_a4', 'BEAM0000/geolocation/elev_highestreturn_a5', 'BEAM0000/geolocation/elev_highestreturn_a6', 'BEAM0000/geolocation/elev_lowestmode_a1', 'BEAM0000/geolocation/elev_lowestmode_a2', 'BEAM0000/geolocation/elev_lowestmode_a3', 'BEAM0000/geolocation/elev_lowestmode_a4', 'BEAM0000/geolocation/elev_lowestmode_a5', 'BEAM0000/geolocation/elev_lowestmode_a6', 'BEAM0000/geolocation/elev_lowestreturn_a1', 'BEAM0000/geolocation/elev_lowestreturn_a2', 'BEAM0000/geolocation/elev_lowestreturn_a3', 'BEAM0000/geolocation/elev_lowestreturn_a4', 'BEAM0000/geolocation/elev_lowestreturn_a5', 'BEAM0000/geolocation/elev_lowestreturn_a6', 'BEAM0000/geolocation/elevation_1gfit', 'BEAM0000/geolocation/elevs_allmodes_a1', 'BEAM0000/geolocation/elevs_allmodes_a2', 'BEAM0000/geolocation/elevs_allmodes_a3', 'BEAM0000/geolocation/elevs_allmodes_a4', 'BEAM0000/geolocation/elevs_allmodes_a5', 'BEAM0000/geolocation/elevs_allmodes_a6', 'BEAM0000/geolocation/energy_lowestmode_a1', 'BEAM0000/geolocation/energy_lowestmode_a2', 'BEAM0000/geolocation/energy_lowestmode_a3', 'BEAM0000/geolocation/energy_lowestmode_a4', 'BEAM0000/geolocation/energy_lowestmode_a5', 'BEAM0000/geolocation/energy_lowestmode_a6', 'BEAM0000/geolocation/lat_highestreturn_a1', 'BEAM0000/geolocation/lat_highestreturn_a2', 'BEAM0000/geolocation/lat_highestreturn_a3', 'BEAM0000/geolocation/lat_highestreturn_a4', 'BEAM0000/geolocation/lat_highestreturn_a5', 'BEAM0000/geolocation/lat_highestreturn_a6', 'BEAM0000/geolocation/lat_lowestmode_a1', 'BEAM0000/geolocation/lat_lowestmode_a2', 'BEAM0000/geolocation/lat_lowestmode_a3', 'BEAM0000/geolocation/lat_lowestmode_a4', 'BEAM0000/geolocation/lat_lowestmode_a5', 'BEAM0000/geolocation/lat_lowestmode_a6', 'BEAM0000/geolocation/lat_lowestreturn_a1', 'BEAM0000/geolocation/lat_lowestreturn_a2', 'BEAM0000/geolocation/lat_lowestreturn_a3', 'BEAM0000/geolocation/lat_lowestreturn_a4', 'BEAM0000/geolocation/lat_lowestreturn_a5', 'BEAM0000/geolocation/lat_lowestreturn_a6', 'BEAM0000/geolocation/latitude_1gfit', 'BEAM0000/geolocation/lats_allmodes_a1', 'BEAM0000/geolocation/lats_allmodes_a2', 'BEAM0000/geolocation/lats_allmodes_a3', 'BEAM0000/geolocation/lats_allmodes_a4', 'BEAM0000/geolocation/lats_allmodes_a5', 'BEAM0000/geolocation/lats_allmodes_a6', 'BEAM0000/geolocation/lon_highestreturn_a1', 'BEAM0000/geolocation/lon_highestreturn_a2', 'BEAM0000/geolocation/lon_highestreturn_a3', 'BEAM0000/geolocation/lon_highestreturn_a4', 'BEAM0000/geolocation/lon_highestreturn_a5', 'BEAM0000/geolocation/lon_highestreturn_a6', 'BEAM0000/geolocation/lon_lowestmode_a1', 'BEAM0000/geolocation/lon_lowestmode_a2', 'BEAM0000/geolocation/lon_lowestmode_a3', 'BEAM0000/geolocation/lon_lowestmode_a4', 'BEAM0000/geolocation/lon_lowestmode_a5', 'BEAM0000/geolocation/lon_lowestmode_a6', 'BEAM0000/geolocation/lon_lowestreturn_a1', 'BEAM0000/geolocation/lon_lowestreturn_a2', 'BEAM0000/geolocation/lon_lowestreturn_a3', 'BEAM0000/geolocation/lon_lowestreturn_a4', 'BEAM0000/geolocation/lon_lowestreturn_a5', 'BEAM0000/geolocation/lon_lowestreturn_a6', 'BEAM0000/geolocation/longitude_1gfit', 'BEAM0000/geolocation/lons_allmodes_a1', 'BEAM0000/geolocation/lons_allmodes_a2', 'BEAM0000/geolocation/lons_allmodes_a3', 'BEAM0000/geolocation/lons_allmodes_a4', 'BEAM0000/geolocation/lons_allmodes_a5', 'BEAM0000/geolocation/lons_allmodes_a6', 'BEAM0000/geolocation/num_detectedmodes_a1', 'BEAM0000/geolocation/num_detectedmodes_a2', 'BEAM0000/geolocation/num_detectedmodes_a3', 'BEAM000 ...
# Beam: BEAM0001
# ['BEAM0001/ancillary/l2a_alg_count', 'BEAM0001/beam', 'BEAM0001/channel', 'BEAM0001/degrade_flag', 'BEAM0001/delta_time', 'BEAM0001/digital_elevation_model', 'BEAM0001/digital_elevation_model_srtm', 'BEAM0001/elev_highestreturn', 'BEAM0001/elev_lowestmode', 'BEAM0001/elevation_bias_flag', 'BEAM0001/elevation_bin0_error', 'BEAM0001/energy_total', 'BEAM0001/geolocation/elev_highestreturn_a1', 'BEAM0001/geolocation/elev_highestreturn_a2', 'BEAM0001/geolocation/elev_highestreturn_a3', 'BEAM0001/geolocation/elev_highestreturn_a4', 'BEAM0001/geolocation/elev_highestreturn_a5', 'BEAM0001/geolocation/elev_highestreturn_a6', 'BEAM0001/geolocation/elev_lowestmode_a1', 'BEAM0001/geolocation/elev_lowestmode_a2', 'BEAM0001/geolocation/elev_lowestmode_a3', 'BEAM0001/geolocation/elev_lowestmode_a4', 'BEAM0001/geolocation/elev_lowestmode_a5', 'BEAM0001/geolocation/elev_lowestmode_a6', 'BEAM0001/geolocation/elev_lowestreturn_a1', 'BEAM0001/geolocation/elev_lowestreturn_a2', 'BEAM0001/geolocation/elev_lowestreturn_a3', 'BEAM0001/geolocation/elev_lowestreturn_a4', 'BEAM0001/geolocation/elev_lowestreturn_a5', 'BEAM0001/geolocation/elev_lowestreturn_a6', 'BEAM0001/geolocation/elevation_1gfit', 'BEAM0001/geolocation/elevs_allmodes_a1', 'BEAM0001/geolocation/elevs_allmodes_a2', 'BEAM0001/geolocation/elevs_allmodes_a3', 'BEAM0001/geolocation/elevs_allmodes_a4', 'BEAM0001/geolocation/elevs_allmodes_a5', 'BEAM0001/geolocation/elevs_allmodes_a6', 'BEAM0001/geolocation/energy_lowestmode_a1', 'BEAM0001/geolocation/energy_lowestmode_a2', 'BEAM0001/geolocation/energy_lowestmode_a3', 'BEAM0001/geolocation/energy_lowestmode_a4', 'BEAM0001/geolocation/energy_lowestmode_a5', 'BEAM0001/geolocation/energy_lowestmode_a6', 'BEAM0001/geolocation/lat_highestreturn_a1', 'BEAM0001/geolocation/lat_highestreturn_a2', 'BEAM0001/geolocation/lat_highestreturn_a3', 'BEAM0001/geolocation/lat_highestreturn_a4', 'BEAM0001/geolocation/lat_highestreturn_a5', 'BEAM0001/geolocation/lat_highestreturn_a6', 'BEAM0001/geolocation/lat_lowestmode_a1', 'BEAM0001/geolocation/lat_lowestmode_a2', 'BEAM0001/geolocation/lat_lowestmode_a3', 'BEAM0001/geolocation/lat_lowestmode_a4', 'BEAM0001/geolocation/lat_lowestmode_a5', 'BEAM0001/geolocation/lat_lowestmode_a6', 'BEAM0001/geolocation/lat_lowestreturn_a1', 'BEAM0001/geolocation/lat_lowestreturn_a2', 'BEAM0001/geolocation/lat_lowestreturn_a3', 'BEAM0001/geolocation/lat_lowestreturn_a4', 'BEAM0001/geolocation/lat_lowestreturn_a5', 'BEAM0001/geolocation/lat_lowestreturn_a6', 'BEAM0001/geolocation/latitude_1gfit', 'BEAM0001/geolocation/lats_allmodes_a1', 'BEAM0001/geolocation/lats_allmodes_a2', 'BEAM0001/geolocation/lats_allmodes_a3', 'BEAM0001/geolocation/lats_allmodes_a4', 'BEAM0001/geolocation/lats_allmodes_a5', 'BEAM0001/geolocation/lats_allmodes_a6', 'BEAM0001/geolocation/lon_highestreturn_a1', 'BEAM0001/geolocation/lon_highestreturn_a2', 'BEAM0001/geolocation/lon_highestreturn_a3', 'BEAM0001/geolocation/lon_highestreturn_a4', 'BEAM0001/geolocation/lon_highestreturn_a5', 'BEAM0001/geolocation/lon_highestreturn_a6', 'BEAM0001/geolocation/lon_lowestmode_a1', 'BEAM0001/geolocation/lon_lowestmode_a2', 'BEAM0001/geolocation/lon_lowestmode_a3', 'BEAM0001/geolocation/lon_lowestmode_a4', 'BEAM0001/geolocation/lon_lowestmode_a5', 'BEAM0001/geolocation/lon_lowestmode_a6', 'BEAM0001/geolocation/lon_lowestreturn_a1', 'BEAM0001/geolocation/lon_lowestreturn_a2', 'BEAM0001/geolocation/lon_lowestreturn_a3', 'BEAM0001/geolocation/lon_lowestreturn_a4', 'BEAM0001/geolocation/lon_lowestreturn_a5', 'BEAM0001/geolocation/lon_lowestreturn_a6', 'BEAM0001/geolocation/longitude_1gfit', 'BEAM0001/geolocation/lons_allmodes_a1', 'BEAM0001/geolocation/lons_allmodes_a2', 'BEAM0001/geolocation/lons_allmodes_a3', 'BEAM0001/geolocation/lons_allmodes_a4', 'BEAM0001/geolocation/lons_allmodes_a5', 'BEAM0001/geolocation/lons_allmodes_a6', 'BEAM0001/geolocation/num_detectedmodes_a1', 'BEAM0001/geolocation/num_detectedmodes_a2', 'BEAM0001/geolocation/num_detectedmodes_a3', 'BEAM000 ...
# Beam: BEAM0010
# ['BEAM0010/ancillary/l2a_alg_count', 'BEAM0010/beam', 'BEAM0010/channel', 'BEAM0010/degrade_flag', 'BEAM0010/delta_time', 'BEAM0010/digital_elevation_model', 'BEAM0010/digital_elevation_model_srtm', 'BEAM0010/elev_highestreturn', 'BEAM0010/elev_lowestmode', 'BEAM0010/elevation_bias_flag', 'BEAM0010/elevation_bin0_error', 'BEAM0010/energy_total', 'BEAM0010/geolocation/elev_highestreturn_a1', 'BEAM0010/geolocation/elev_highestreturn_a2', 'BEAM0010/geolocation/elev_highestreturn_a3', 'BEAM0010/geolocation/elev_highestreturn_a4', 'BEAM0010/geolocation/elev_highestreturn_a5', 'BEAM0010/geolocation/elev_highestreturn_a6', 'BEAM0010/geolocation/elev_lowestmode_a1', 'BEAM0010/geolocation/elev_lowestmode_a2', 'BEAM0010/geolocation/elev_lowestmode_a3', 'BEAM0010/geolocation/elev_lowestmode_a4', 'BEAM0010/geolocation/elev_lowestmode_a5', 'BEAM0010/geolocation/elev_lowestmode_a6', 'BEAM0010/geolocation/elev_lowestreturn_a1', 'BEAM0010/geolocation/elev_lowestreturn_a2', 'BEAM0010/geolocation/elev_lowestreturn_a3', 'BEAM0010/geolocation/elev_lowestreturn_a4', 'BEAM0010/geolocation/elev_lowestreturn_a5', 'BEAM0010/geolocation/elev_lowestreturn_a6', 'BEAM0010/geolocation/elevation_1gfit', 'BEAM0010/geolocation/elevs_allmodes_a1', 'BEAM0010/geolocation/elevs_allmodes_a2', 'BEAM0010/geolocation/elevs_allmodes_a3', 'BEAM0010/geolocation/elevs_allmodes_a4', 'BEAM0010/geolocation/elevs_allmodes_a5', 'BEAM0010/geolocation/elevs_allmodes_a6', 'BEAM0010/geolocation/energy_lowestmode_a1', 'BEAM0010/geolocation/energy_lowestmode_a2', 'BEAM0010/geolocation/energy_lowestmode_a3', 'BEAM0010/geolocation/energy_lowestmode_a4', 'BEAM0010/geolocation/energy_lowestmode_a5', 'BEAM0010/geolocation/energy_lowestmode_a6', 'BEAM0010/geolocation/lat_highestreturn_a1', 'BEAM0010/geolocation/lat_highestreturn_a2', 'BEAM0010/geolocation/lat_highestreturn_a3', 'BEAM0010/geolocation/lat_highestreturn_a4', 'BEAM0010/geolocation/lat_highestreturn_a5', 'BEAM0010/geolocation/lat_highestreturn_a6', 'BEAM0010/geolocation/lat_lowestmode_a1', 'BEAM0010/geolocation/lat_lowestmode_a2', 'BEAM0010/geolocation/lat_lowestmode_a3', 'BEAM0010/geolocation/lat_lowestmode_a4', 'BEAM0010/geolocation/lat_lowestmode_a5', 'BEAM0010/geolocation/lat_lowestmode_a6', 'BEAM0010/geolocation/lat_lowestreturn_a1', 'BEAM0010/geolocation/lat_lowestreturn_a2', 'BEAM0010/geolocation/lat_lowestreturn_a3', 'BEAM0010/geolocation/lat_lowestreturn_a4', 'BEAM0010/geolocation/lat_lowestreturn_a5', 'BEAM0010/geolocation/lat_lowestreturn_a6', 'BEAM0010/geolocation/latitude_1gfit', 'BEAM0010/geolocation/lats_allmodes_a1', 'BEAM0010/geolocation/lats_allmodes_a2', 'BEAM0010/geolocation/lats_allmodes_a3', 'BEAM0010/geolocation/lats_allmodes_a4', 'BEAM0010/geolocation/lats_allmodes_a5', 'BEAM0010/geolocation/lats_allmodes_a6', 'BEAM0010/geolocation/lon_highestreturn_a1', 'BEAM0010/geolocation/lon_highestreturn_a2', 'BEAM0010/geolocation/lon_highestreturn_a3', 'BEAM0010/geolocation/lon_highestreturn_a4', 'BEAM0010/geolocation/lon_highestreturn_a5', 'BEAM0010/geolocation/lon_highestreturn_a6', 'BEAM0010/geolocation/lon_lowestmode_a1', 'BEAM0010/geolocation/lon_lowestmode_a2', 'BEAM0010/geolocation/lon_lowestmode_a3', 'BEAM0010/geolocation/lon_lowestmode_a4', 'BEAM0010/geolocation/lon_lowestmode_a5', 'BEAM0010/geolocation/lon_lowestmode_a6', 'BEAM0010/geolocation/lon_lowestreturn_a1', 'BEAM0010/geolocation/lon_lowestreturn_a2', 'BEAM0010/geolocation/lon_lowestreturn_a3', 'BEAM0010/geolocation/lon_lowestreturn_a4', 'BEAM0010/geolocation/lon_lowestreturn_a5', 'BEAM0010/geolocation/lon_lowestreturn_a6', 'BEAM0010/geolocation/longitude_1gfit', 'BEAM0010/geolocation/lons_allmodes_a1', 'BEAM0010/geolocation/lons_allmodes_a2', 'BEAM0010/geolocation/lons_allmodes_a3', 'BEAM0010/geolocation/lons_allmodes_a4', 'BEAM0010/geolocation/lons_allmodes_a5', 'BEAM0010/geolocation/lons_allmodes_a6', 'BEAM0010/geolocation/num_detectedmodes_a1', 'BEAM0010/geolocation/num_detectedmodes_a2', 'BEAM0010/geolocation/num_detectedmodes_a3', 'BEAM001 ...
# Beam: BEAM0011
# ['BEAM0011/ancillary/l2a_alg_count', 'BEAM0011/beam', 'BEAM0011/channel', 'BEAM0011/degrade_flag', 'BEAM0011/delta_time', 'BEAM0011/digital_elevation_model', 'BEAM0011/digital_elevation_model_srtm', 'BEAM0011/elev_highestreturn', 'BEAM0011/elev_lowestmode', 'BEAM0011/elevation_bias_flag', 'BEAM0011/elevation_bin0_error', 'BEAM0011/energy_total', 'BEAM0011/geolocation/elev_highestreturn_a1', 'BEAM0011/geolocation/elev_highestreturn_a2', 'BEAM0011/geolocation/elev_highestreturn_a3', 'BEAM0011/geolocation/elev_highestreturn_a4', 'BEAM0011/geolocation/elev_highestreturn_a5', 'BEAM0011/geolocation/elev_highestreturn_a6', 'BEAM0011/geolocation/elev_lowestmode_a1', 'BEAM0011/geolocation/elev_lowestmode_a2', 'BEAM0011/geolocation/elev_lowestmode_a3', 'BEAM0011/geolocation/elev_lowestmode_a4', 'BEAM0011/geolocation/elev_lowestmode_a5', 'BEAM0011/geolocation/elev_lowestmode_a6', 'BEAM0011/geolocation/elev_lowestreturn_a1', 'BEAM0011/geolocation/elev_lowestreturn_a2', 'BEAM0011/geolocation/elev_lowestreturn_a3', 'BEAM0011/geolocation/elev_lowestreturn_a4', 'BEAM0011/geolocation/elev_lowestreturn_a5', 'BEAM0011/geolocation/elev_lowestreturn_a6', 'BEAM0011/geolocation/elevation_1gfit', 'BEAM0011/geolocation/elevs_allmodes_a1', 'BEAM0011/geolocation/elevs_allmodes_a2', 'BEAM0011/geolocation/elevs_allmodes_a3', 'BEAM0011/geolocation/elevs_allmodes_a4', 'BEAM0011/geolocation/elevs_allmodes_a5', 'BEAM0011/geolocation/elevs_allmodes_a6', 'BEAM0011/geolocation/energy_lowestmode_a1', 'BEAM0011/geolocation/energy_lowestmode_a2', 'BEAM0011/geolocation/energy_lowestmode_a3', 'BEAM0011/geolocation/energy_lowestmode_a4', 'BEAM0011/geolocation/energy_lowestmode_a5', 'BEAM0011/geolocation/energy_lowestmode_a6', 'BEAM0011/geolocation/lat_highestreturn_a1', 'BEAM0011/geolocation/lat_highestreturn_a2', 'BEAM0011/geolocation/lat_highestreturn_a3', 'BEAM0011/geolocation/lat_highestreturn_a4', 'BEAM0011/geolocation/lat_highestreturn_a5', 'BEAM0011/geolocation/lat_highestreturn_a6', 'BEAM0011/geolocation/lat_lowestmode_a1', 'BEAM0011/geolocation/lat_lowestmode_a2', 'BEAM0011/geolocation/lat_lowestmode_a3', 'BEAM0011/geolocation/lat_lowestmode_a4', 'BEAM0011/geolocation/lat_lowestmode_a5', 'BEAM0011/geolocation/lat_lowestmode_a6', 'BEAM0011/geolocation/lat_lowestreturn_a1', 'BEAM0011/geolocation/lat_lowestreturn_a2', 'BEAM0011/geolocation/lat_lowestreturn_a3', 'BEAM0011/geolocation/lat_lowestreturn_a4', 'BEAM0011/geolocation/lat_lowestreturn_a5', 'BEAM0011/geolocation/lat_lowestreturn_a6', 'BEAM0011/geolocation/latitude_1gfit', 'BEAM0011/geolocation/lats_allmodes_a1', 'BEAM0011/geolocation/lats_allmodes_a2', 'BEAM0011/geolocation/lats_allmodes_a3', 'BEAM0011/geolocation/lats_allmodes_a4', 'BEAM0011/geolocation/lats_allmodes_a5', 'BEAM0011/geolocation/lats_allmodes_a6', 'BEAM0011/geolocation/lon_highestreturn_a1', 'BEAM0011/geolocation/lon_highestreturn_a2', 'BEAM0011/geolocation/lon_highestreturn_a3', 'BEAM0011/geolocation/lon_highestreturn_a4', 'BEAM0011/geolocation/lon_highestreturn_a5', 'BEAM0011/geolocation/lon_highestreturn_a6', 'BEAM0011/geolocation/lon_lowestmode_a1', 'BEAM0011/geolocation/lon_lowestmode_a2', 'BEAM0011/geolocation/lon_lowestmode_a3', 'BEAM0011/geolocation/lon_lowestmode_a4', 'BEAM0011/geolocation/lon_lowestmode_a5', 'BEAM0011/geolocation/lon_lowestmode_a6', 'BEAM0011/geolocation/lon_lowestreturn_a1', 'BEAM0011/geolocation/lon_lowestreturn_a2', 'BEAM0011/geolocation/lon_lowestreturn_a3', 'BEAM0011/geolocation/lon_lowestreturn_a4', 'BEAM0011/geolocation/lon_lowestreturn_a5', 'BEAM0011/geolocation/lon_lowestreturn_a6', 'BEAM0011/geolocation/longitude_1gfit', 'BEAM0011/geolocation/lons_allmodes_a1', 'BEAM0011/geolocation/lons_allmodes_a2', 'BEAM0011/geolocation/lons_allmodes_a3', 'BEAM0011/geolocation/lons_allmodes_a4', 'BEAM0011/geolocation/lons_allmodes_a5', 'BEAM0011/geolocation/lons_allmodes_a6', 'BEAM0011/geolocation/num_detectedmodes_a1', 'BEAM0011/geolocation/num_detectedmodes_a2', 'BEAM0011/geolocation/num_detectedmodes_a3', 'BEAM001 ...
# Beam: BEAM0101
# ['BEAM0101/ancillary/l2a_alg_count', 'BEAM0101/beam', 'BEAM0101/channel', 'BEAM0101/degrade_flag', 'BEAM0101/delta_time', 'BEAM0101/digital_elevation_model', 'BEAM0101/digital_elevation_model_srtm', 'BEAM0101/elev_highestreturn', 'BEAM0101/elev_lowestmode', 'BEAM0101/elevation_bias_flag', 'BEAM0101/elevation_bin0_error', 'BEAM0101/energy_total', 'BEAM0101/geolocation/elev_highestreturn_a1', 'BEAM0101/geolocation/elev_highestreturn_a2', 'BEAM0101/geolocation/elev_highestreturn_a3', 'BEAM0101/geolocation/elev_highestreturn_a4', 'BEAM0101/geolocation/elev_highestreturn_a5', 'BEAM0101/geolocation/elev_highestreturn_a6', 'BEAM0101/geolocation/elev_lowestmode_a1', 'BEAM0101/geolocation/elev_lowestmode_a2', 'BEAM0101/geolocation/elev_lowestmode_a3', 'BEAM0101/geolocation/elev_lowestmode_a4', 'BEAM0101/geolocation/elev_lowestmode_a5', 'BEAM0101/geolocation/elev_lowestmode_a6', 'BEAM0101/geolocation/elev_lowestreturn_a1', 'BEAM0101/geolocation/elev_lowestreturn_a2', 'BEAM0101/geolocation/elev_lowestreturn_a3', 'BEAM0101/geolocation/elev_lowestreturn_a4', 'BEAM0101/geolocation/elev_lowestreturn_a5', 'BEAM0101/geolocation/elev_lowestreturn_a6', 'BEAM0101/geolocation/elevation_1gfit', 'BEAM0101/geolocation/elevs_allmodes_a1', 'BEAM0101/geolocation/elevs_allmodes_a2', 'BEAM0101/geolocation/elevs_allmodes_a3', 'BEAM0101/geolocation/elevs_allmodes_a4', 'BEAM0101/geolocation/elevs_allmodes_a5', 'BEAM0101/geolocation/elevs_allmodes_a6', 'BEAM0101/geolocation/energy_lowestmode_a1', 'BEAM0101/geolocation/energy_lowestmode_a2', 'BEAM0101/geolocation/energy_lowestmode_a3', 'BEAM0101/geolocation/energy_lowestmode_a4', 'BEAM0101/geolocation/energy_lowestmode_a5', 'BEAM0101/geolocation/energy_lowestmode_a6', 'BEAM0101/geolocation/lat_highestreturn_a1', 'BEAM0101/geolocation/lat_highestreturn_a2', 'BEAM0101/geolocation/lat_highestreturn_a3', 'BEAM0101/geolocation/lat_highestreturn_a4', 'BEAM0101/geolocation/lat_highestreturn_a5', 'BEAM0101/geolocation/lat_highestreturn_a6', 'BEAM0101/geolocation/lat_lowestmode_a1', 'BEAM0101/geolocation/lat_lowestmode_a2', 'BEAM0101/geolocation/lat_lowestmode_a3', 'BEAM0101/geolocation/lat_lowestmode_a4', 'BEAM0101/geolocation/lat_lowestmode_a5', 'BEAM0101/geolocation/lat_lowestmode_a6', 'BEAM0101/geolocation/lat_lowestreturn_a1', 'BEAM0101/geolocation/lat_lowestreturn_a2', 'BEAM0101/geolocation/lat_lowestreturn_a3', 'BEAM0101/geolocation/lat_lowestreturn_a4', 'BEAM0101/geolocation/lat_lowestreturn_a5', 'BEAM0101/geolocation/lat_lowestreturn_a6', 'BEAM0101/geolocation/latitude_1gfit', 'BEAM0101/geolocation/lats_allmodes_a1', 'BEAM0101/geolocation/lats_allmodes_a2', 'BEAM0101/geolocation/lats_allmodes_a3', 'BEAM0101/geolocation/lats_allmodes_a4', 'BEAM0101/geolocation/lats_allmodes_a5', 'BEAM0101/geolocation/lats_allmodes_a6', 'BEAM0101/geolocation/lon_highestreturn_a1', 'BEAM0101/geolocation/lon_highestreturn_a2', 'BEAM0101/geolocation/lon_highestreturn_a3', 'BEAM0101/geolocation/lon_highestreturn_a4', 'BEAM0101/geolocation/lon_highestreturn_a5', 'BEAM0101/geolocation/lon_highestreturn_a6', 'BEAM0101/geolocation/lon_lowestmode_a1', 'BEAM0101/geolocation/lon_lowestmode_a2', 'BEAM0101/geolocation/lon_lowestmode_a3', 'BEAM0101/geolocation/lon_lowestmode_a4', 'BEAM0101/geolocation/lon_lowestmode_a5', 'BEAM0101/geolocation/lon_lowestmode_a6', 'BEAM0101/geolocation/lon_lowestreturn_a1', 'BEAM0101/geolocation/lon_lowestreturn_a2', 'BEAM0101/geolocation/lon_lowestreturn_a3', 'BEAM0101/geolocation/lon_lowestreturn_a4', 'BEAM0101/geolocation/lon_lowestreturn_a5', 'BEAM0101/geolocation/lon_lowestreturn_a6', 'BEAM0101/geolocation/longitude_1gfit', 'BEAM0101/geolocation/lons_allmodes_a1', 'BEAM0101/geolocation/lons_allmodes_a2', 'BEAM0101/geolocation/lons_allmodes_a3', 'BEAM0101/geolocation/lons_allmodes_a4', 'BEAM0101/geolocation/lons_allmodes_a5', 'BEAM0101/geolocation/lons_allmodes_a6', 'BEAM0101/geolocation/num_detectedmodes_a1', 'BEAM0101/geolocation/num_detectedmodes_a2', 'BEAM0101/geolocation/num_detectedmodes_a3', 'BEAM010 ...
# Beam: BEAM0110
# ['BEAM0110/ancillary/l2a_alg_count', 'BEAM0110/beam', 'BEAM0110/channel', 'BEAM0110/degrade_flag', 'BEAM0110/delta_time', 'BEAM0110/digital_elevation_model', 'BEAM0110/digital_elevation_model_srtm', 'BEAM0110/elev_highestreturn', 'BEAM0110/elev_lowestmode', 'BEAM0110/elevation_bias_flag', 'BEAM0110/elevation_bin0_error', 'BEAM0110/energy_total', 'BEAM0110/geolocation/elev_highestreturn_a1', 'BEAM0110/geolocation/elev_highestreturn_a2', 'BEAM0110/geolocation/elev_highestreturn_a3', 'BEAM0110/geolocation/elev_highestreturn_a4', 'BEAM0110/geolocation/elev_highestreturn_a5', 'BEAM0110/geolocation/elev_highestreturn_a6', 'BEAM0110/geolocation/elev_lowestmode_a1', 'BEAM0110/geolocation/elev_lowestmode_a2', 'BEAM0110/geolocation/elev_lowestmode_a3', 'BEAM0110/geolocation/elev_lowestmode_a4', 'BEAM0110/geolocation/elev_lowestmode_a5', 'BEAM0110/geolocation/elev_lowestmode_a6', 'BEAM0110/geolocation/elev_lowestreturn_a1', 'BEAM0110/geolocation/elev_lowestreturn_a2', 'BEAM0110/geolocation/elev_lowestreturn_a3', 'BEAM0110/geolocation/elev_lowestreturn_a4', 'BEAM0110/geolocation/elev_lowestreturn_a5', 'BEAM0110/geolocation/elev_lowestreturn_a6', 'BEAM0110/geolocation/elevation_1gfit', 'BEAM0110/geolocation/elevs_allmodes_a1', 'BEAM0110/geolocation/elevs_allmodes_a2', 'BEAM0110/geolocation/elevs_allmodes_a3', 'BEAM0110/geolocation/elevs_allmodes_a4', 'BEAM0110/geolocation/elevs_allmodes_a5', 'BEAM0110/geolocation/elevs_allmodes_a6', 'BEAM0110/geolocation/energy_lowestmode_a1', 'BEAM0110/geolocation/energy_lowestmode_a2', 'BEAM0110/geolocation/energy_lowestmode_a3', 'BEAM0110/geolocation/energy_lowestmode_a4', 'BEAM0110/geolocation/energy_lowestmode_a5', 'BEAM0110/geolocation/energy_lowestmode_a6', 'BEAM0110/geolocation/lat_highestreturn_a1', 'BEAM0110/geolocation/lat_highestreturn_a2', 'BEAM0110/geolocation/lat_highestreturn_a3', 'BEAM0110/geolocation/lat_highestreturn_a4', 'BEAM0110/geolocation/lat_highestreturn_a5', 'BEAM0110/geolocation/lat_highestreturn_a6', 'BEAM0110/geolocation/lat_lowestmode_a1', 'BEAM0110/geolocation/lat_lowestmode_a2', 'BEAM0110/geolocation/lat_lowestmode_a3', 'BEAM0110/geolocation/lat_lowestmode_a4', 'BEAM0110/geolocation/lat_lowestmode_a5', 'BEAM0110/geolocation/lat_lowestmode_a6', 'BEAM0110/geolocation/lat_lowestreturn_a1', 'BEAM0110/geolocation/lat_lowestreturn_a2', 'BEAM0110/geolocation/lat_lowestreturn_a3', 'BEAM0110/geolocation/lat_lowestreturn_a4', 'BEAM0110/geolocation/lat_lowestreturn_a5', 'BEAM0110/geolocation/lat_lowestreturn_a6', 'BEAM0110/geolocation/latitude_1gfit', 'BEAM0110/geolocation/lats_allmodes_a1', 'BEAM0110/geolocation/lats_allmodes_a2', 'BEAM0110/geolocation/lats_allmodes_a3', 'BEAM0110/geolocation/lats_allmodes_a4', 'BEAM0110/geolocation/lats_allmodes_a5', 'BEAM0110/geolocation/lats_allmodes_a6', 'BEAM0110/geolocation/lon_highestreturn_a1', 'BEAM0110/geolocation/lon_highestreturn_a2', 'BEAM0110/geolocation/lon_highestreturn_a3', 'BEAM0110/geolocation/lon_highestreturn_a4', 'BEAM0110/geolocation/lon_highestreturn_a5', 'BEAM0110/geolocation/lon_highestreturn_a6', 'BEAM0110/geolocation/lon_lowestmode_a1', 'BEAM0110/geolocation/lon_lowestmode_a2', 'BEAM0110/geolocation/lon_lowestmode_a3', 'BEAM0110/geolocation/lon_lowestmode_a4', 'BEAM0110/geolocation/lon_lowestmode_a5', 'BEAM0110/geolocation/lon_lowestmode_a6', 'BEAM0110/geolocation/lon_lowestreturn_a1', 'BEAM0110/geolocation/lon_lowestreturn_a2', 'BEAM0110/geolocation/lon_lowestreturn_a3', 'BEAM0110/geolocation/lon_lowestreturn_a4', 'BEAM0110/geolocation/lon_lowestreturn_a5', 'BEAM0110/geolocation/lon_lowestreturn_a6', 'BEAM0110/geolocation/longitude_1gfit', 'BEAM0110/geolocation/lons_allmodes_a1', 'BEAM0110/geolocation/lons_allmodes_a2', 'BEAM0110/geolocation/lons_allmodes_a3', 'BEAM0110/geolocation/lons_allmodes_a4', 'BEAM0110/geolocation/lons_allmodes_a5', 'BEAM0110/geolocation/lons_allmodes_a6', 'BEAM0110/geolocation/num_detectedmodes_a1', 'BEAM0110/geolocation/num_detectedmodes_a2', 'BEAM0110/geolocation/num_detectedmodes_a3', 'BEAM011 ...
# Beam: BEAM1000
# ['BEAM1000/ancillary/l2a_alg_count', 'BEAM1000/beam', 'BEAM1000/channel', 'BEAM1000/degrade_flag', 'BEAM1000/delta_time', 'BEAM1000/digital_elevation_model', 'BEAM1000/digital_elevation_model_srtm', 'BEAM1000/elev_highestreturn', 'BEAM1000/elev_lowestmode', 'BEAM1000/elevation_bias_flag', 'BEAM1000/elevation_bin0_error', 'BEAM1000/energy_total', 'BEAM1000/geolocation/elev_highestreturn_a1', 'BEAM1000/geolocation/elev_highestreturn_a2', 'BEAM1000/geolocation/elev_highestreturn_a3', 'BEAM1000/geolocation/elev_highestreturn_a4', 'BEAM1000/geolocation/elev_highestreturn_a5', 'BEAM1000/geolocation/elev_highestreturn_a6', 'BEAM1000/geolocation/elev_lowestmode_a1', 'BEAM1000/geolocation/elev_lowestmode_a2', 'BEAM1000/geolocation/elev_lowestmode_a3', 'BEAM1000/geolocation/elev_lowestmode_a4', 'BEAM1000/geolocation/elev_lowestmode_a5', 'BEAM1000/geolocation/elev_lowestmode_a6', 'BEAM1000/geolocation/elev_lowestreturn_a1', 'BEAM1000/geolocation/elev_lowestreturn_a2', 'BEAM1000/geolocation/elev_lowestreturn_a3', 'BEAM1000/geolocation/elev_lowestreturn_a4', 'BEAM1000/geolocation/elev_lowestreturn_a5', 'BEAM1000/geolocation/elev_lowestreturn_a6', 'BEAM1000/geolocation/elevation_1gfit', 'BEAM1000/geolocation/elevs_allmodes_a1', 'BEAM1000/geolocation/elevs_allmodes_a2', 'BEAM1000/geolocation/elevs_allmodes_a3', 'BEAM1000/geolocation/elevs_allmodes_a4', 'BEAM1000/geolocation/elevs_allmodes_a5', 'BEAM1000/geolocation/elevs_allmodes_a6', 'BEAM1000/geolocation/energy_lowestmode_a1', 'BEAM1000/geolocation/energy_lowestmode_a2', 'BEAM1000/geolocation/energy_lowestmode_a3', 'BEAM1000/geolocation/energy_lowestmode_a4', 'BEAM1000/geolocation/energy_lowestmode_a5', 'BEAM1000/geolocation/energy_lowestmode_a6', 'BEAM1000/geolocation/lat_highestreturn_a1', 'BEAM1000/geolocation/lat_highestreturn_a2', 'BEAM1000/geolocation/lat_highestreturn_a3', 'BEAM1000/geolocation/lat_highestreturn_a4', 'BEAM1000/geolocation/lat_highestreturn_a5', 'BEAM1000/geolocation/lat_highestreturn_a6', 'BEAM1000/geolocation/lat_lowestmode_a1', 'BEAM1000/geolocation/lat_lowestmode_a2', 'BEAM1000/geolocation/lat_lowestmode_a3', 'BEAM1000/geolocation/lat_lowestmode_a4', 'BEAM1000/geolocation/lat_lowestmode_a5', 'BEAM1000/geolocation/lat_lowestmode_a6', 'BEAM1000/geolocation/lat_lowestreturn_a1', 'BEAM1000/geolocation/lat_lowestreturn_a2', 'BEAM1000/geolocation/lat_lowestreturn_a3', 'BEAM1000/geolocation/lat_lowestreturn_a4', 'BEAM1000/geolocation/lat_lowestreturn_a5', 'BEAM1000/geolocation/lat_lowestreturn_a6', 'BEAM1000/geolocation/latitude_1gfit', 'BEAM1000/geolocation/lats_allmodes_a1', 'BEAM1000/geolocation/lats_allmodes_a2', 'BEAM1000/geolocation/lats_allmodes_a3', 'BEAM1000/geolocation/lats_allmodes_a4', 'BEAM1000/geolocation/lats_allmodes_a5', 'BEAM1000/geolocation/lats_allmodes_a6', 'BEAM1000/geolocation/lon_highestreturn_a1', 'BEAM1000/geolocation/lon_highestreturn_a2', 'BEAM1000/geolocation/lon_highestreturn_a3', 'BEAM1000/geolocation/lon_highestreturn_a4', 'BEAM1000/geolocation/lon_highestreturn_a5', 'BEAM1000/geolocation/lon_highestreturn_a6', 'BEAM1000/geolocation/lon_lowestmode_a1', 'BEAM1000/geolocation/lon_lowestmode_a2', 'BEAM1000/geolocation/lon_lowestmode_a3', 'BEAM1000/geolocation/lon_lowestmode_a4', 'BEAM1000/geolocation/lon_lowestmode_a5', 'BEAM1000/geolocation/lon_lowestmode_a6', 'BEAM1000/geolocation/lon_lowestreturn_a1', 'BEAM1000/geolocation/lon_lowestreturn_a2', 'BEAM1000/geolocation/lon_lowestreturn_a3', 'BEAM1000/geolocation/lon_lowestreturn_a4', 'BEAM1000/geolocation/lon_lowestreturn_a5', 'BEAM1000/geolocation/lon_lowestreturn_a6', 'BEAM1000/geolocation/longitude_1gfit', 'BEAM1000/geolocation/lons_allmodes_a1', 'BEAM1000/geolocation/lons_allmodes_a2', 'BEAM1000/geolocation/lons_allmodes_a3', 'BEAM1000/geolocation/lons_allmodes_a4', 'BEAM1000/geolocation/lons_allmodes_a5', 'BEAM1000/geolocation/lons_allmodes_a6', 'BEAM1000/geolocation/num_detectedmodes_a1', 'BEAM1000/geolocation/num_detectedmodes_a2', 'BEAM1000/geolocation/num_detectedmodes_a3', 'BEAM100 ...
# Beam: BEAM1011
# ['BEAM1011/ancillary/l2a_alg_count', 'BEAM1011/beam', 'BEAM1011/channel', 'BEAM1011/degrade_flag', 'BEAM1011/delta_time', 'BEAM1011/digital_elevation_model', 'BEAM1011/digital_elevation_model_srtm', 'BEAM1011/elev_highestreturn', 'BEAM1011/elev_lowestmode', 'BEAM1011/elevation_bias_flag', 'BEAM1011/elevation_bin0_error', 'BEAM1011/energy_total', 'BEAM1011/geolocation/elev_highestreturn_a1', 'BEAM1011/geolocation/elev_highestreturn_a2', 'BEAM1011/geolocation/elev_highestreturn_a3', 'BEAM1011/geolocation/elev_highestreturn_a4', 'BEAM1011/geolocation/elev_highestreturn_a5', 'BEAM1011/geolocation/elev_highestreturn_a6', 'BEAM1011/geolocation/elev_lowestmode_a1', 'BEAM1011/geolocation/elev_lowestmode_a2', 'BEAM1011/geolocation/elev_lowestmode_a3', 'BEAM1011/geolocation/elev_lowestmode_a4', 'BEAM1011/geolocation/elev_lowestmode_a5', 'BEAM1011/geolocation/elev_lowestmode_a6', 'BEAM1011/geolocation/elev_lowestreturn_a1', 'BEAM1011/geolocation/elev_lowestreturn_a2', 'BEAM1011/geolocation/elev_lowestreturn_a3', 'BEAM1011/geolocation/elev_lowestreturn_a4', 'BEAM1011/geolocation/elev_lowestreturn_a5', 'BEAM1011/geolocation/elev_lowestreturn_a6', 'BEAM1011/geolocation/elevation_1gfit', 'BEAM1011/geolocation/elevs_allmodes_a1', 'BEAM1011/geolocation/elevs_allmodes_a2', 'BEAM1011/geolocation/elevs_allmodes_a3', 'BEAM1011/geolocation/elevs_allmodes_a4', 'BEAM1011/geolocation/elevs_allmodes_a5', 'BEAM1011/geolocation/elevs_allmodes_a6', 'BEAM1011/geolocation/energy_lowestmode_a1', 'BEAM1011/geolocation/energy_lowestmode_a2', 'BEAM1011/geolocation/energy_lowestmode_a3', 'BEAM1011/geolocation/energy_lowestmode_a4', 'BEAM1011/geolocation/energy_lowestmode_a5', 'BEAM1011/geolocation/energy_lowestmode_a6', 'BEAM1011/geolocation/lat_highestreturn_a1', 'BEAM1011/geolocation/lat_highestreturn_a2', 'BEAM1011/geolocation/lat_highestreturn_a3', 'BEAM1011/geolocation/lat_highestreturn_a4', 'BEAM1011/geolocation/lat_highestreturn_a5', 'BEAM1011/geolocation/lat_highestreturn_a6', 'BEAM1011/geolocation/lat_lowestmode_a1', 'BEAM1011/geolocation/lat_lowestmode_a2', 'BEAM1011/geolocation/lat_lowestmode_a3', 'BEAM1011/geolocation/lat_lowestmode_a4', 'BEAM1011/geolocation/lat_lowestmode_a5', 'BEAM1011/geolocation/lat_lowestmode_a6', 'BEAM1011/geolocation/lat_lowestreturn_a1', 'BEAM1011/geolocation/lat_lowestreturn_a2', 'BEAM1011/geolocation/lat_lowestreturn_a3', 'BEAM1011/geolocation/lat_lowestreturn_a4', 'BEAM1011/geolocation/lat_lowestreturn_a5', 'BEAM1011/geolocation/lat_lowestreturn_a6', 'BEAM1011/geolocation/latitude_1gfit', 'BEAM1011/geolocation/lats_allmodes_a1', 'BEAM1011/geolocation/lats_allmodes_a2', 'BEAM1011/geolocation/lats_allmodes_a3', 'BEAM1011/geolocation/lats_allmodes_a4', 'BEAM1011/geolocation/lats_allmodes_a5', 'BEAM1011/geolocation/lats_allmodes_a6', 'BEAM1011/geolocation/lon_highestreturn_a1', 'BEAM1011/geolocation/lon_highestreturn_a2', 'BEAM1011/geolocation/lon_highestreturn_a3', 'BEAM1011/geolocation/lon_highestreturn_a4', 'BEAM1011/geolocation/lon_highestreturn_a5', 'BEAM1011/geolocation/lon_highestreturn_a6', 'BEAM1011/geolocation/lon_lowestmode_a1', 'BEAM1011/geolocation/lon_lowestmode_a2', 'BEAM1011/geolocation/lon_lowestmode_a3', 'BEAM1011/geolocation/lon_lowestmode_a4', 'BEAM1011/geolocation/lon_lowestmode_a5', 'BEAM1011/geolocation/lon_lowestmode_a6', 'BEAM1011/geolocation/lon_lowestreturn_a1', 'BEAM1011/geolocation/lon_lowestreturn_a2', 'BEAM1011/geolocation/lon_lowestreturn_a3', 'BEAM1011/geolocation/lon_lowestreturn_a4', 'BEAM1011/geolocation/lon_lowestreturn_a5', 'BEAM1011/geolocation/lon_lowestreturn_a6', 'BEAM1011/geolocation/longitude_1gfit', 'BEAM1011/geolocation/lons_allmodes_a1', 'BEAM1011/geolocation/lons_allmodes_a2', 'BEAM1011/geolocation/lons_allmodes_a3', 'BEAM1011/geolocation/lons_allmodes_a4', 'BEAM1011/geolocation/lons_allmodes_a5', 'BEAM1011/geolocation/lons_allmodes_a6', 'BEAM1011/geolocation/num_detectedmodes_a1', 'BEAM1011/geolocation/num_detectedmodes_a2', 'BEAM1011/geolocation/num_detectedmodes_a3', 'BEAM101 ...

# %% [markdown]
# # To dos:
# - Try reproducing issue on OSCAR terminal
# - Request machine on OSCAR that gives interactive access, NOT schedule a job
# - Start interactive session, use correct Py ver, load libs, run code
# - File mapping
# - Do 1 concat and see how much memory it uses
#
# - Beam & channel are relevant
# - Exclude RH's in PCA
# - Want meta-data, not data per se
# - SHAP after ML output
# - Google Earth Engine

# %%
# """We will now create a massive dataframe with all the data from each beam from each file."""
# dataframes = []
# for ds in all_datasets:
#   print(f'Loading dataset {ds}')
#   # Load the dataset into a Pandas dataframe
#   df = pd.DataFrame(data=f[ds][()])
#   dataframes.append(df)
#   print(f"Appended {df}. Dataset shape: {df.shape}")
# 
# complete_df = pd.concat(dataframes)
# # Display or save the final dataframe
# print("Final dataframe shape:", complete_df.shape)
# complete_df

output_file = "complete_df_new.csv"  # Output file for incremental saving
save_mode = "w"  # Write mode for the first chunk, then switch to append
header = True  # Include header only for the first chunk

for ds in all_datasets:
    print(f'Loading dataset {ds}')
    # Load the dataset into a Pandas dataframe
    df = pd.DataFrame(data=f[ds][()])
    print(f"Dataset shape: {df.shape}")
    
    # Save the dataframe to a CSV file incrementally
    df.to_csv(output_file, mode=save_mode, header=header, index=False)
    save_mode = "a"  # Switch to append mode for subsequent chunks
    header = False  # Exclude header for subsequent chunks
    
    if not header:
        # Append columns to the existing file
        # Read only the number of rows in the current chunk to match
        existing_df = pd.read_csv(output_file, nrows=df.shape[0])

        # Combine the existing data with the new chunk column-wise
        combined_df = pd.concat([existing_df, df], axis=1)

        # Overwrite the file with the updated content
        combined_df.to_csv(output_file, mode='w', header=True, index=False)

print(f"Data has been saved incrementally to {output_file}")
# Out:
# Loading dataset BEAM0000/ancillary/l2a_alg_count
# Dataset shape: (1, 1)
# Loading dataset BEAM0000/beam
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/channel
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/degrade_flag
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/delta_time
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/digital_elevation_model
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/digital_elevation_model_srtm
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/elev_highestreturn
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/elev_lowestmode
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/elevation_bias_flag
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/elevation_bin0_error
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/energy_total
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_highestreturn_a1
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_highestreturn_a2
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_highestreturn_a3
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_highestreturn_a4
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_highestreturn_a5
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_highestreturn_a6
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestmode_a1
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestmode_a2
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestmode_a3
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestmode_a4
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestmode_a5
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestmode_a6
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestreturn_a1
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestreturn_a2
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestreturn_a3
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestreturn_a4
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestreturn_a5
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elev_lowestreturn_a6
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elevation_1gfit
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/elevs_allmodes_a1
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/elevs_allmodes_a2
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/elevs_allmodes_a3
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/elevs_allmodes_a4
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/elevs_allmodes_a5
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/elevs_allmodes_a6
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/energy_lowestmode_a1
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/energy_lowestmode_a2
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/energy_lowestmode_a3
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/energy_lowestmode_a4
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/energy_lowestmode_a5
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/energy_lowestmode_a6
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_highestreturn_a1
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_highestreturn_a2
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_highestreturn_a3
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_highestreturn_a4
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_highestreturn_a5
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_highestreturn_a6
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestmode_a1
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestmode_a2
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestmode_a3
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestmode_a4
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestmode_a5
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestmode_a6
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestreturn_a1
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestreturn_a2
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestreturn_a3
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestreturn_a4
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestreturn_a5
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lat_lowestreturn_a6
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/latitude_1gfit
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lats_allmodes_a1
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/lats_allmodes_a2
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/lats_allmodes_a3
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/lats_allmodes_a4
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/lats_allmodes_a5
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/lats_allmodes_a6
# Dataset shape: (167280, 20)
# Loading dataset BEAM0000/geolocation/lon_highestreturn_a1
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lon_highestreturn_a2
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lon_highestreturn_a3
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lon_highestreturn_a4
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lon_highestreturn_a5
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lon_highestreturn_a6
# Dataset shape: (167280, 1)
# Loading dataset BEAM0000/geolocation/lon_lowestmode_a1
# Dataset shape: (167280, 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 39
#      36         combined_df = pd.concat([existing_df, df], axis=1)
#      38         # Overwrite the file with the updated content
# ---> 39         combined_df.to_csv(output_file, mode='w', header=True, index=False)
#      41 print(f"Data has been saved incrementally to {output_file}")
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\io\formats\csvs.py:270, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
# --> 270     self._save()
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\io\formats\csvs.py:275, in CSVFormatter._save(self)
#     273 if self._need_to_save_header:
#     274     self._save_header()
# --> 275 self._save_body()
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\io\formats\csvs.py:313, in CSVFormatter._save_body(self)
#     311 if start_i >= end_i:
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\io\formats\csvs.py:320, in CSVFormatter._save_chunk(self, start_i, end_i)
#     317 slicer = slice(start_i, end_i)
#     318 df = self.obj.iloc[slicer]
# --> 320 res = df._get_values_for_csv(**self._number_format)
#     321 data = list(res._iter_column_arrays())
#     323 ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\core\frame.py:1410, in DataFrame._get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#    1400 def _get_values_for_csv(
#    1401     self,
#    1402     *,
#    (...)
#    1408 ) -> Self:
#    1409     # helper used by to_csv
# -> 1410     mgr = self._mgr.get_values_for_csv(
#    1411         float_format=float_format,
#    1412         date_format=date_format,
#    1413         decimal=decimal,
#    1414         na_rep=na_rep,
#    1415         quoting=quoting,
#    1416     )
#    1417     # error: Incompatible return value type (got "DataFrame", expected "Self")
#    1418     return self._constructor_from_mgr(mgr, axes=mgr.axes)
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\core\internals\managers.py:466, in BaseBlockManager.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     459 def get_values_for_csv(
#     460     self, *, float_format, date_format, decimal, na_rep: str = "nan", quoting=None
#     461 ) -> Self:
#     462     """
#     463     Convert values to native types (strings / python objects) that are used
#     464     in formatting (repr / csv).
#     465     """
# --> 466     return self.apply(
#     467         "get_values_for_csv",
#     468         na_rep=na_rep,
#     469         quoting=quoting,
#     470         float_format=float_format,
#     471         date_format=date_format,
#     472         decimal=decimal,
#     473     )
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\core\internals\blocks.py:788, in Block.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     779 """convert to our native types format"""
#     780 result = get_values_for_csv(
#     781     self.values,
#     782     na_rep=na_rep,
#    (...)
#     786     decimal=decimal,
#     787 )
# --> 788 return self.make_block(result)
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\core\internals\blocks.py:287, in Block.make_block(self, values, placement, refs)
#     285 if placement is None:
#     286     placement = self._mgr_locs
# --> 287 if self.is_extension:
#     288     values = ensure_block_shape(values, ndim=self.ndim)
#     290 return new_block(values, placement=placement, ndim=self.ndim, refs=refs)
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\.conda\envs\GEDI\Lib\site-packages\pandas\core\internals\blocks.py:214, in Block.is_extension(self)
#     209 @final
#     210 @cache_readonly
#     211 def is_object(self) -> bool:
#     212     return self.values.dtype == _dtype_obj
# --> 214 @final
#     215 @cache_readonly
#     216 def is_extension(self) -> bool:
#     217     return not lib.is_np_dtype(self.values.dtype)
#     219 @final
#     220 @cache_readonly
#     221 def _can_consolidate(self) -> bool:
#     222     # We _could_ consolidate for DatetimeTZDtype but don't for now.
#
# KeyboardInterrupt:

# %% [markdown]
# ### Incremental PCA

# %%
df = pd.read_csv("complete_df.csv", nrows=5)
print(df)
# Out:
#    0
# 0  6
# 1  0
# 2  0
# 3  0
# 4  0

# %%
from sklearn.decomposition import IncrementalPCA


# Define file path and parameters
input_file = "complete_df.csv"
chunk_size = 100000  # Number of rows per chunk
n_components = 3  # Number of principal components

# Initialize IncrementalPCA
ipca = IncrementalPCA(n_components=n_components)

# Process the CSV in chunks
chunks = pd.read_csv(input_file, chunksize=chunk_size)
print("Processing the data in chunks...")
for chunk in chunks:
    # Convert to NumPy array
    chunk_data = chunk.to_numpy()
    print("Chunk shape:", chunk.shape)
    # Incrementally fit the PCA model on the chunk
    ipca.partial_fit(chunk_data)

# Transform the data in chunks and save the results
output_file = "reduced_data.csv"
chunks = pd.read_csv(input_file, chunksize=chunk_size)
for chunk in chunks:
    chunk_data = chunk.to_numpy()
    reduced_data = ipca.transform(chunk_data)
    
    # Save reduced data incrementally
    pd.DataFrame(reduced_data).to_csv(output_file, mode='a', header=False, index=False)

print("PCA completed and reduced data saved to", output_file)
# Out:
# Processing the data in chunks...
# Chunk shape: (100000, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 20
#      18     print("Chunk shape:", chunk.shape)
#      19     # Incrementally fit the PCA model on the chunk
# ---> 20     ipca.partial_fit(chunk_data)
#      22 # Transform the data in chunks and save the results
#      23 output_file = "reduced_data.csv"
#
# File ~\.conda\envs\GEDI\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\.conda\envs\GEDI\Lib\site-packages\sklearn\decomposition\_incremental_pca.py:299, in IncrementalPCA.partial_fit(self, X, y, check_input)
#     293     raise ValueError(
#     294         "n_components=%r invalid for n_features=%d, need "
#     295         "more rows than columns for IncrementalPCA "
#     296         "processing" % (self.n_components, n_features)
#     297     )
#     298 elif not self.n_components <= n_samples:
# --> 299     raise ValueError(
#     300         "n_components=%r must be less or equal to "
#     301         "the batch number of samples "
#     302         "%d." % (self.n_components, n_samples)
#     303     )
#     304 else:
#     305     self.n_components_ = self.n_components
#
# ValueError: n_components=3 must be less or equal to the batch number of samples 1.

# %% [markdown]
# ### Adding z-scores of each RH metric to the dataframe

# %%
rh_nums = [25, 50, 75, 85, 95]
for i in rh_nums:
    col_name = f'*RH {i}'
    complete_df[f'{col_name} Z Score'] = (complete_df[col_name] - complete_df[col_name].mean()) / complete_df[col_name].std()

complete_df
# Out:
#                                                 File Name Beam Name  \
# 928     GEDI02_A_2021050140102_O12405_02_T10912_02_003...  BEAM0000
# 930     GEDI02_A_2021050140102_O12405_02_T10912_02_003...  BEAM0000
# 931     GEDI02_A_2021050140102_O12405_02_T10912_02_003...  BEAM0000
# 932     GEDI02_A_2021050140102_O12405_02_T10912_02_003...  BEAM0000
# 933     GEDI02_A_2021050140102_O12405_02_T10912_02_003...  BEAM0000
# ...                                                   ...       ...
# 154849  GEDI02_A_2021086153349_O12964_03_T08275_02_003...  BEAM1011
# 154850  GEDI02_A_2021086153349_O12964_03_T08275_02_003...  BEAM1011
# 154851  GEDI02_A_2021086153349_O12964_03_T08275_02_003...  BEAM1011
# 154852  GEDI02_A_2021086153349_O12964_03_T08275_02_003...  BEAM1011
# 154853  GEDI02_A_2021086153349_O12964_03_T08275_02_003...  BEAM1011
#
#          Shot Number   Latitude   Longitude  Tandem-X DEM  SRTM DEM  \
# 928     1.240500e+17  26.949514 -140.210474     -999999.0 -999999.0
# 930     1.240500e+17  26.949901 -140.210092     -999999.0 -999999.0
# 931     1.240500e+17  26.950094 -140.209901     -999999.0 -999999.0
# 932     1.240500e+17  26.950287 -140.209711     -999999.0 -999999.0
# 933     1.240500e+17  26.950481 -140.209520     -999999.0 -999999.0
# ...              ...        ...         ...           ...       ...
# 154849  1.296411e+17   5.315743  125.769220     -999999.0 -999999.0
# 154850  1.296411e+17   5.315323  125.769519     -999999.0 -999999.0
# 154851  1.296411e+17   5.314903  125.769818     -999999.0 -999999.0
# 154852  1.296411e+17   5.314483  125.770117     -999999.0 -999999.0
# 154853  1.296411e+17   5.314063  125.770416     -999999.0 -999999.0
#
#         *Elevation (m)  *Canopy Elevation (m)  *RH 25  ...  *RH 95  \
# 928         -25.178839             -22.930853   -0.63  ...    1.76
# 930         -25.532187             -23.583931   -0.86  ...    1.42
# 931         -25.935125             -23.649672   -0.82  ...    1.72
# 932         -25.398439             -23.300318   -0.71  ...    1.61
# 933         -25.742947             -23.457495   -0.63  ...    1.76
# ...                ...                    ...     ...  ...     ...
# 154849       65.394615              68.387398   -0.97  ...    1.90
# 154850       65.368126              68.248680   -1.04  ...    1.83
# 154851       65.539238              68.681664   -0.93  ...    2.09
# 154852       65.537354              68.193443   -0.82  ...    1.94
# 154853       65.450089              68.031364   -0.86  ...    1.87
#
#         Quality Flag  Degrade Flag  Sensitivity  Selected Algorithm  \
# 928              1.0           0.0     0.525841                 1.0
# 930              1.0           0.0     0.626149                 1.0
# 931              1.0           0.0     0.648748                 1.0
# 932              1.0           0.0     0.545459                 1.0
# 933              1.0           0.0     0.636309                 1.0
# ...              ...           ...          ...                 ...
# 154849           1.0           0.0     0.867145                 1.0
# 154850           1.0           0.0     0.840408                 1.0
# 154851           1.0           0.0     0.787433                 1.0
# 154852           1.0           0.0     0.631403                 1.0
# 154853           1.0           0.0     0.632411                 1.0
#
#         *RH 25 Z Score  *RH 50 Z Score  *RH 75 Z Score  *RH 85 Z Score  \
# 928           0.079091       -0.223630       -0.352021       -0.404941
# 930          -0.035554       -0.283883       -0.416731       -0.465439
# 931          -0.015616       -0.257104       -0.371194       -0.427124
# 932           0.039214       -0.247061       -0.380781       -0.435190
# 933           0.079091       -0.223630       -0.352021       -0.413008
# ...                ...             ...             ...             ...
# 154849       -0.090384       -0.270493       -0.371194       -0.413008
# 154850       -0.125276       -0.293925       -0.387971       -0.429141
# 154851       -0.070446       -0.247061       -0.344831       -0.382759
# 154852       -0.015616       -0.247061       -0.352021       -0.398892
# 154853       -0.035554       -0.257104       -0.361608       -0.413008
#
#         *RH 95 Z Score
# 928          -0.482947
# 930          -0.537166
# 931          -0.489325
# 932          -0.506867
# 933          -0.482947
# ...                ...
# 154849       -0.460621
# 154850       -0.471784
# 154851       -0.430322
# 154852       -0.454243
# 154853       -0.465405
#
# [666736 rows x 23 columns]
